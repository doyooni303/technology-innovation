# %%
import os

os.listdir("/home/doyooni303/projects/technology-innovation/data/pdfs")
# Out:
# ['An efficient reinforcement learning based charging data delivery scheme in VANET-enhanced smart grid.pdf',
#  'Defect detection in battery electrode production using supervised and unsupervised learning with laser speckle photometry data.pdf',
#  'Machine learning in lithium‐ion battery cell production a comprehensive mapping study.pdf',
#  'Probabilistic constrained load flow considering integration of wind power generation and electric vehicles.pdf',
#  'Transfer Learning-Based Framework Enhanced by Deep Generative Model for Cold-Start Forecasting of Residential EV Charging Behavior.pdf',
#  'Multi-criteria and real-time control of continuous battery cell production steps using deep learning.pdf',
#  'Mass load prediction for lithium-ion battery electrode clean production A machine learning approach.pdf',
#  'A novel ensembling of CNN-A-LSTM for IoT electric vehicle charging stations based on intrusion detection system.pdf',
# ...
